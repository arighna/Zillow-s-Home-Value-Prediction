# %%
import os
import sys
import pandas as pd
import numpy as np
import math

import matplotlib.pylab as plt
# %matplotlib inline

# %%
# print ('hello')
# zillow_data  = pd.read_csv(os.getcwd()+'/../Data/'+'properties_2016.csv')
# zillow_data_results  = pd.read_csv(os.getcwd()+'/../Data/'+'train_2016_v2.csv')
# print (zillow_data.shape)
# print (zillow_data_results.shape)
# zillow_data.to_pickle(os.getcwd()+'/../Data/'+'zillow_data')
# zillow_data_results.to_pickle(os.getcwd()+'/../Data/'+'zillow_data_results')

# %%
# zillow_data = pd.read_pickle(os.getcwd()+'/../Data/'+'zillow_data')
# zillow_data_results = pd.read_pickle(os.getcwd()+'/../Data/'+'zillow_data_results')

# zillow_data = pd.merge(zillow_data, zillow_data_results, how='inner', left_on='parcelid', right_on='parcelid')
# print (zillow_data.shape)
# zillow_data.to_pickle(os.getcwd()+'/../Data/'+'zillow_data_full')

# %%
zillow_data = pd.read_pickle(os.getcwd()+'/../Data/'+'zillow_data_full')
# zillow_data.head()

# %%
# print (len(zillow_data['parcelid']), len(set(zillow_data['parcelid'])))
# zillow_data.drop_duplicates(subset='parcelid', keep=False, inplace=True)
# print (len(zillow_data['parcelid']), len(set(zillow_data['parcelid'])))

# %%
# len(zillow_data['propertyzoningdesc'].unique())
# zillow_data['propertyzoningdesc'].value_counts()

# %%
zillow_data.drop(['parcelid','transactiondate'],axis=1,inplace=True)
# zillow_data.head()

# %%
# zillow_data.isnull().sum()

# %%
# zillow_data.isnull().values.ravel().sum()
# zillow_data.dropna().shape[0]

# %%
# zillow_data.apply(lambda x: x.nunique())

# %%
# len(zillow_data['propertyzoningdesc'].unique())
# zillow_data['propertyzoningdesc'].value_counts()
zillow_data.drop(['propertycountylandusecode', 'propertyzoningdesc','longitude'],axis=1,inplace=True)

# %%
count = zillow_data.apply(lambda x: x.nunique())
columns = zillow_data.columns
categorical = []
numerical = []
for i in range(zillow_data.shape[1]):
    if count[i] == 1:
        zillow_data.drop(columns[i],axis=1,inplace=True)
        continue
    print (columns[i])
    if count[i] < 20:
        
        categorical.append(columns[i])
        print (zillow_data[columns[i]].value_counts())
        
        ax = sns.boxplot(x=columns[i], y="logerror", data=zillow_data)
        
        fig = ax.get_figure()
        plt.show(block=False)
        plt.close(fig)
        
        ax = sns.countplot(x=columns[i], data=zillow_data, palette="Greens_d");
        
    else:
        numerical.append(columns[i])
        sns.jointplot(x=columns[i], y="logerror", data=zillow_data)
        
        fig = ax.get_figure()
        plt.show(block=False)
        plt.close(fig)
        
        sns.distplot(zillow_data[columns[i]].dropna(), hist=True)
        
    fig = ax.get_figure()
    plt.show(block=False)
    plt.close(fig)
# Out:
# airconditioningtypeid
# 1.0     26668
# 13.0     1833
# 5.0       215
# 11.0       63
# 9.0         1
# 3.0         1
# Name: airconditioningtypeid, dtype: int64
# architecturalstyletypeid
# 7.0     221
# 8.0      16
# 2.0      11
# 21.0      8
# 3.0       4
# 10.0      1
# Name: architecturalstyletypeid, dtype: int64
# basementsqft
# bathroomcnt
# bedroomcnt
# 3.0     35447
# 2.0     22357
# 4.0     20279
# 5.0      5077
# 1.0      3897
# 0.0      1421
# 6.0      1120
# 8.0       274
# 7.0       234
# 9.0        91
# 10.0       35
# 12.0       22
# 11.0       12
# 16.0        4
# 14.0        3
# 13.0        1
# 15.0        1
# Name: bedroomcnt, dtype: int64
# buildingqualitytypeid
# 7.0     29310
# 4.0     23839
# 1.0      2627
# 10.0     1461
# 12.0      119
# 8.0         5
# 6.0         2
# 11.0        1
# Name: buildingqualitytypeid, dtype: int64
# calculatedbathnbr
# finishedfloor1squarefeet
# calculatedfinishedsquarefeet
# finishedsquarefeet12
# finishedsquarefeet13
# ...

# %%
# numerical_data = zillow_data[numerical]

# # sns.pairplot(numerical_data)
# g = sns.PairGrid(numerical_data)
# g.map_diag(sns.kdeplot)
# g.map_offdiag(sns.kdeplot, cmap="Blues_d", n_levels=6);

# %%
# drop rows with too many nans
# combine low cardinal col values which have less impact on log error
remove outliers
check variables one by one
regression forest
encoding and neural network

# %%
nan_count = zillow_data.isnull().sum(axis=1)
nan_count.hist()
for i in range(len(nan_count)):
    if nan_count[i] > 10:
        pass
#         print (zillow_data.iloc[i,1])

len([1 for item in nan_count if item>20])

# %%
plt.ylim(-0.1, 0.1)
sns.boxplot(x=zillow_data.columns[categorical[3]], y="logerror", data=zillow_data)
